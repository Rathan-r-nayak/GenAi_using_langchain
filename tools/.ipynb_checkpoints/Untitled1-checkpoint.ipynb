# %%
from langchain_core.tools import tool
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_ollama import OllamaLLM
from langchain_core.messages import HumanMessage

# %%
load_dotenv()
# llm = ChatGroq(model="llama-3.1-8b-instant")
llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
@tool
def multiply(a:int,b:int)->int:
    """Multiply two given numbers"""
    return a * b

@tool
def addition(a:int,b:int)->int:
    """Addition of two given numbers"""
    return a + b

# %%
def getTools():
    return [multiply,addition]

# %%
llm_with_tools = llm.bind_tools(getTools())

result = llm_with_tools.invoke("multiply 3 with 5")
result
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'tzcmjtyn2', 'function': {'arguments': '{"a":3,"b":5}', 'name': 'multiply'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 279, 'total_tokens': 298, 'completion_time': 0.036560275, 'prompt_time': 0.018902738, 'queue_time': 0.052933012, 'total_time': 0.055463013}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_e750f72ec9', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--3b0a28c4-1da8-4f38-87ce-1d8393ff9743-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3, 'b': 5}, 'id': 'tzcmjtyn2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 279, 'output_tokens': 19, 'total_tokens': 298})

# %%
result.tool_calls
# Out:
# [{'name': 'multiply',
#   'args': {'a': 3, 'b': 5},
#   'id': 'tzcmjtyn2',
#   'type': 'tool_call'}]

# %%
result.tool_calls[0]['args']
# Out:
# {'a': 3, 'b': 5}

# %%
multiply.invoke(result.tool_calls[0]['args'])
# Out:
# 15

# %%
multiply.invoke(result.tool_calls[0])
# Out:
# ToolMessage(content='15', name='multiply', tool_call_id='tzcmjtyn2')

# %%
a = input("Enter a value")
print(a)
# Out:
# Enter a value 5
# 5

# %%
messages = []
val = 1;
while(val == 1):
    query = input("Prompt your query here")
    messages.append(HumanMessage(query))
    result = llm_with_tools.invoke(messages)
    messages.append(result)
    val = int(input("1-continue    0-stop"))
# Out:
# Prompt your query here add 77 with 55
# 1-continue    0-stop 0

# %%
messages
# Out:
# [HumanMessage(content='add 77 with 55', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'ts7rxrmw5', 'function': {'arguments': '{"a":77,"b":55}', 'name': 'addition'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 279, 'total_tokens': 298, 'completion_time': 0.030571014, 'prompt_time': 0.016601981, 'queue_time': 0.049435799, 'total_time': 0.047172995}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--669c8919-32e9-415c-bd6f-7584663918de-0', tool_calls=[{'name': 'addition', 'args': {'a': 77, 'b': 55}, 'id': 'ts7rxrmw5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 279, 'output_tokens': 19, 'total_tokens': 298})]

# %%
multiply.invoke(messages[1].tool_calls[0])
# Out:
# ToolMessage(content='132', name='addition', tool_call_id='ts7rxrmw5')

# %%
messages[1].tool_calls
# Out:
# [{'name': 'addition',
#   'args': {'a': 77, 'b': 55},
#   'id': 'ts7rxrmw5',
#   'type': 'tool_call'}]

# %%
addition.invoke(messages[3].tool_calls[0])
# Out:
# ToolMessage(content='32', name='addition', tool_call_id='ybcgre2pe')

# %%
messages[3].tool_calls
# Out:
# [{'name': 'multiply',
#   'args': {'a': 7, 'b': 25},
#   'id': 'ybcgre2pe',
#   'type': 'tool_call'}]

# %%
messages.append(addition.invoke(messages[1].tool_calls[0]))
messages.append(
llm_with_tools.invoke(messages).content
# Out:
# 'The result of the addition is 132.'
