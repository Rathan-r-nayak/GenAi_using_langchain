# %%
from langchain_community.document_loaders import CSVLoader

# %%
loader = CSVLoader("data/NetworkHospitalList.csv")

# %%
docs = loader.load()
type(docs)
# Out:
# list

# %%
docs[0].metadata
# Out:
# {'source': 'data/NetworkHospitalList.csv', 'row': 0}

# %%
docs[0].page_content
# Out:
# 'Name: centre For Sight - Nehru Nagar\nAddress: E-2/228 Ambedkar Road\nState: Uttar Pradesh\nCity: Ghaziabad\nPinCode: 201002\nPhone: 9650044492\nEmail: TPADESK7@CENTREFORSIGHT.NET\n: '
