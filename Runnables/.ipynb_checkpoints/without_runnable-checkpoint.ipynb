# %%
from langchain_ollama import OllamaLLM
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser,PydanticOutputParser
from langchain_core.prompts import PromptTemplate
from pydantic import BaseModel,Field
from typing import Literal
from dotenv import load_dotenv

# %%
class FakeLLM:
    def __init__(self):
        load_dotenv()
        self.llm = ChatGroq(model="llama-3.1-8b-instant")
        print("LLM initialized")
        
    def predict(self, prompt):
        return {'response' : self.llm.invoke(prompt).content}

# %%
class FakePromptTemplate:
    def __init__(self,template,input_variables):
        print("promt template initialize")
        self.template = template
        self.input_variables = input_variables

    def format(self,input_dict):
        return self.template.format(**input_dict)

# %%
class FakeOutputParser:
    def __init__(self):
        print("output parser initialized")
    def invoke(self,output):
        return output['response']

# %%
template = FakePromptTemplate(
    template = "Generate 2 interesting thing about {topic}",
    input_variables = ['topic']
)
prompt = template.format({"topic":"Artificial Intelligence"})
# Out:
# promt template initialize

# %%
llm = FakeLLM()
result = llm.predict(prompt)

parser = FakeOutputParser()
print(parser.invoke(result))
# Out:
# LLM initialized
# output parser initialized
# Here are two interesting things about Artificial Intelligence:
#
# 1. **AI can Create New Art and Music**: Recent advancements in AI have enabled the creation of new art and music. For example, the AI program "Amper Music" can create custom music tracks in minutes, while "Prisma" can transform photos into works of art in the style of famous artists like Van Gogh or Picasso. This raises interesting questions about the role of creativity in AI and whether machines can truly be considered "artists."
#
# 2. **DeepMind's AlphaGo AI can Learn from Experience and Improve over Time**: Google's DeepMind AI program, AlphaGo, is a master of the game of Go. What's remarkable about AlphaGo is that it can learn from its experiences and improve its gameplay over time. In 2016, AlphaGo defeated a human world champion in Go, marking a major milestone in AI research. This ability to learn and improve over time is a key characteristic of human intelligence, and AlphaGo's achievements demonstrate the potential of AI to surpass human capabilities in certain domains.
